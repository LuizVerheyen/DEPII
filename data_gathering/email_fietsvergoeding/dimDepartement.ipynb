# %%
import pandas as pd

import os
import sys

from pathlib import Path

ROOT = Path().resolve().parents[1] 
sys.path.append(str(ROOT))

# %%
df = pd.read_excel(ROOT / "data" / "dimAndFactDepartement_Data.xlsx", encoding='urf-8')
df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df = pd.read_excel(ROOT / "data" / "dimAndFactDepartement_Data.xlsx", encoding='urf-8')
#       2 df.head()
#
# TypeError: read_excel() got an unexpected keyword argument 'encoding'
